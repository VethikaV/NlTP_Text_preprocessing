# %%
import nltk

paragraph =  """I have three visions for India. In 3000 years of our history, people from all over
               the world have come and invaded us, captured our lands, conquered our minds.
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours.
               Yet we have not done this to any other nation. We have not conquered anyone.
               We have not grabbed their land, their culture,
               their history and tried to enforce our way of life on them.
               Why? Because we respect the freedom of others.That is why my
               first vision is that of freedom. I believe that India got its first vision of
               this in 1857, when we started the War of Independence. It is this freedom that
               we must protect and nurture and build on. If we are not free, no one will respect us.
               My second vision for India’s development. For fifty years we have been a developing nation.
               It is time we see ourselves as a developed nation. We are among the top 5 nations of the world
               in terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.
               Our achievements are being globally recognised today. Yet we lack the self-confidence to
               see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?
               I have a third vision. India must stand up to the world. Because I believe that unless India
               stands up to the world, no one will respect us. Only strength respects strength. We must be
               strong not only as a military power but also as an economic power. Both must go hand-in-hand.
               My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of
               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.
               I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.
               I see four milestones in my career"""

# %%
# Cleaning the texts
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Download the 'stopwords' dataset
nltk.download('punkt_tab')
nltk.download('stopwords')
ps = PorterStemmer()
wordnet=WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sentences = nltk.sent_tokenize(paragraph)
#sentences = ['he is a good boy','she is a good girl','boy & girl are good']

corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
 ##cv = CountVectorizer(max_features=100)
cv = CountVectorizer(max_features=500,ngram_range=(1,3))
X = cv.fit_transform(corpus).toarray()

cv.vocabulary_
# Out:
# {'three': 281,
#  'vision': 312,
#  'india': 137,
#  'three vision': 286,
#  'vision india': 314,
#  'three vision india': 287,
#  'year': 333,
#  'histori': 130,
#  'peopl': 204,
#  'world': 326,
#  'come': 37,
#  'invad': 145,
#  'us': 305,
#  'captur': 30,
#  'land': 151,
#  'conquer': 43,
#  'mind': 171,
#  'year histori': 336,
#  'histori peopl': 131,
#  'peopl world': 205,
#  'world come': 327,
#  'come invad': 38,
#  'invad us': 146,
#  'us captur': 306,
#  'captur land': 31,
#  'land conquer': 152,
#  'conquer mind': 45,
#  'year histori peopl': 337,
#  'histori peopl world': 132,
#  'peopl world come': 206,
#  'world come invad': 328,
#  'come invad us': 39,
#  'invad us captur': 147,
#  'us captur land': 307,
#  'captur land conquer': 32,
#  'land conquer mind': 153,
#  'alexand': 3,
#  'onward': 196,
#  'greek': 122,
#  'turk': 299,
#  'mogul': 172,
#  'portugues': 210,
#  'british': 23,
#  'french': 99,
#  'dutch': 66,
#  'came': 27,
#  'loot': 159,
#  'took': 292,
#  'alexand onward': 4,
#  'onward greek': 197,
#  'greek turk': 123,
#  'turk mogul': 300,
#  'mogul portugues': 173,
#  'portugues british': 211,
#  'british french': 24,
#  'french dutch': 100,
#  'dutch came': 67,
#  'came loot': 28,
#  'loot us': 160,
#  'us took': 308,
#  'alexand onward greek': 5,
#  'onward greek turk': 198,
#  'greek turk mogul': 124,
#  'turk mogul portugues': 301,
#  'mogul portugues british': 174,
#  'portugues british french': 212,
#  'british french dutch': 25,
#  'french dutch came': 101,
#  'dutch came loot': 68,
#  'came loot us': 29,
#  'loot us took': 161,
#  'yet': 338,
#  'done': 59,
#  'nation': 184,
#  'yet done': 339,
#  'done nation': 60,
#  'yet done nation': 340,
#  'anyon': 12,
#  'conquer anyon': 44,
#  'grab': 115,
#  'cultur': 49,
#  'tri': 296,
#  'enforc': 71,
#  'way': 320,
#  'life': 158,
#  'grab land': 116,
#  'land cultur': 154,
#  'cultur histori': 50,
#  'histori tri': 133,
#  'tri enforc': 297,
#  'enforc way': 72,
#  'way life': 321,
#  'grab land cultur': 117,
#  'land cultur histori': 155,
#  'cultur histori tri': 51,
#  'histori tri enforc': 134,
#  'tri enforc way': 298,
#  'enforc way life': 73,
#  'respect': 235,
#  'freedom': 94,
#  'other': 201,
#  'first': 81,
#  'respect freedom': 236,
#  'freedom other': 97,
#  'other first': 202,
#  'first vision': 82,
#  'vision freedom': 313,
#  'respect freedom other': 237,
#  'freedom other first': 98,
#  'other first vision': 203,
#  'first vision freedom': 83,
#  'believ': 15,
#  'got': 112,
#  'start': 265,
#  'war': 318,
#  'independ': 136,
#  'believ india': 16,
#  'india got': 139,
#  'got first': 113,
#  'vision start': 316,
#  'start war': 266,
#  'war independ': 319,
#  'believ india got': 17,
#  'india got first': 140,
#  'got first vision': 114,
#  'first vision start': 84,
#  'vision start war': 317,
#  'start war independ': 267,
#  'must': 175,
#  'protect': 225,
#  'nurtur': 191,
#  'build': 26,
#  'freedom must': 95,
#  'must protect': 178,
#  'protect nurtur': 226,
#  'nurtur build': 192,
#  'freedom must protect': 96,
#  'must protect nurtur': 179,
#  'protect nurtur build': 227,
#  'free': 91,
#  'one': 193,
#  'free one': 92,
#  'one respect': 194,
#  'respect us': 239,
#  'free one respect': 93,
#  'one respect us': 195,
#  'second': 245,
#  'develop': 53,
#  'second vision': 246,
#  'india develop': 138,
#  'second vision india': 247,
#  'vision india develop': 315,
#  'fifti': 78,
#  'fifti year': 79,
#  'year develop': 334,
#  'develop nation': 54,
#  'fifti year develop': 80,
#  'year develop nation': 335,
#  'time': 288,
#  'see': 248,
#  'time see': 289,
#  'see develop': 249,
#  'time see develop': 290,
#  'see develop nation': 250,
#  'among': 9,
#  'top': 293,
#  'term': 277,
#  'gdp': 102,
#  'among top': 10,
#  'top nation': 294,
#  'nation world': 187,
#  'world term': 331,
#  'term gdp': 278,
#  'among top nation': 11,
#  'top nation world': 295,
#  'nation world term': 188,
#  'world term gdp': 332,
#  'percent': 207,
#  'growth': 125,
#  'rate': 228,
#  'area': 13,
#  'percent growth': 208,
#  'growth rate': 126,
#  'rate area': 229,
#  'percent growth rate': 209,
#  'growth rate area': 127,
#  'poverti': 213,
#  'level': 156,
#  'fall': 74,
#  'poverti level': 214,
#  'level fall': 157,
#  'poverti level fall': 215,
#  'achiev': 0,
#  'global': 103,
#  'recognis': 230,
#  'today': 291,
#  'achiev global': 1,
#  'global recognis': 104,
#  'recognis today': 231,
#  'achiev global recognis': 2,
#  'global recognis today': 105,
#  'lack': 148,
#  'self': 253,
#  'confid': 40,
#  'reliant': 232,
#  'assur': 14,
#  'yet lack': 341,
#  'lack self': 149,
#  'self confid': 255,
#  'confid see': 41,
#  'nation self': 185,
#  'self reliant': 257,
#  'reliant self': 233,
#  'self assur': 254,
#  'yet lack self': 342,
#  'lack self confid': 150,
#  'self confid see': 256,
#  'confid see develop': 42,
#  'develop nation self': 55,
#  'nation self reliant': 186,
#  'self reliant self': 258,
#  'reliant self assur': 234,
#  'incorrect': 135,
#  'third': 279,
#  'third vision': 280,
#  'stand': 262,
#  'india must': 141,
#  'must stand': 180,
#  'stand world': 263,
#  'india must stand': 142,
#  'must stand world': 181,
#  'unless': 302,
#  'believ unless': 18,
#  'unless india': 303,
#  'india stand': 143,
#  'world one': 329,
#  'believ unless india': 19,
#  'unless india stand': 304,
#  'india stand world': 144,
#  'stand world one': 264,
#  'world one respect': 330,
#  'strength': 268,
#  'strength respect': 269,
#  'respect strength': 238,
#  'strength respect strength': 270,
#  'strong': 271,
#  'militari': 168,
#  'power': 216,
#  'also': 6,
#  'econom': 69,
#  'must strong': 182,
#  'strong militari': 272,
#  'militari power': 169,
#  'power also': 217,
#  'also econom': 7,
#  'econom power': 70,
#  'must strong militari': 183,
#  'strong militari power': 273,
#  'militari power also': 170,
#  'power also econom': 218,
#  'also econom power': 8,
#  'go': 106,
#  'hand': 128,
#  'must go': 176,
#  'go hand': 107,
#  'hand hand': 129,
#  'must go hand': 177,
#  'go hand hand': 108,
#  'good': 109,
#  'fortun': 85,
#  'work': 322,
#  'great': 118,
#  'good fortun': 110,
#  'fortun work': 86,
#  'work three': 323,
#  'three great': 284,
#  'great mind': 119,
#  'good fortun work': 111,
#  'fortun work three': 87,
#  'work three great': 325,
#  'three great mind': 285,
#  'dr': 61,
#  'vikram': 309,
#  'sarabhai': 240,
#  'dept': 52,
#  'dr vikram': 64,
#  'vikram sarabhai': 310,
#  'sarabhai dept': 241,
#  'dr vikram sarabhai': 65,
#  'vikram sarabhai dept': 311,
#  'space': 259,
#  'professor': 222,
#  'satish': 242,
#  'dhawan': 56,
#  'succeed': 274,
#  'brahm': 20,
#  'prakash': 219,
#  'father': 75,
#  'nuclear': 189,
#  'materi': 165,
#  'space professor': 260,
#  'professor satish': 223,
#  'satish dhawan': 243,
#  'dhawan succeed': 57,
#  'succeed dr': 275,
#  'dr brahm': 62,
#  'brahm prakash': 21,
#  'prakash father': 220,
#  'father nuclear': 76,
#  'nuclear materi': 190,
#  'space professor satish': 261,
#  'professor satish dhawan': 224,
#  'satish dhawan succeed': 244,
#  'dhawan succeed dr': 58,
#  'succeed dr brahm': 276,
#  'dr brahm prakash': 63,
#  'brahm prakash father': 22,
#  'prakash father nuclear': 221,
#  'father nuclear materi': 77,
#  'lucki': 162,
#  'close': 34,
#  'consid': 46,
#  'opportun': 199,
#  'lucki work': 163,
#  'three close': 282,
#  'close consid': 35,
#  'consid great': 47,
#  'great opportun': 120,
#  'opportun life': 200,
#  'lucki work three': 164,
#  'work three close': 324,
#  'three close consid': 283,
#  'close consid great': 36,
#  'consid great opportun': 48,
#  'great opportun life': 121,
#  'four': 88,
#  'mileston': 166,
#  'career': 33,
#  'see four': 251,
#  'four mileston': 89,
#  'mileston career': 167,
#  'see four mileston': 252,
#  'four mileston career': 90}
